# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-2f28dd75aeb6> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 get_ipython().magic('matplotlib inline')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv('unimelb_training.csv',low_memory=False )
df2 = pd.read_csv('unimelb_training.csv',low_memory=False )

# %%
df.head()
# Out:
#    Grant.Application.ID  Grant.Status Sponsor.Code Grant.Category.Code  \
# 0                     1             1          NaN                 NaN
# 1                     2             1           2B                 10A
# 2                     3             1          29A                 10B
# 3                     4             1          40D                 10B
# 4                     5             0          59C                 10A
#
#   Contract.Value.Band...see.note.A Start.date  RFCD.Code.1  RFCD.Percentage.1  \
# 0                               A     8/11/05     280199.0              100.0
# 1                               B    11/11/05     280103.0               30.0
# 2                               A    14/11/05     321004.0               60.0
# 3                               C    15/11/05     270602.0               50.0
# 4                               A    16/11/05     260500.0               34.0
#
# ...

# %%
df2.head()
# Out:
#    Grant.Application.ID  Grant.Status Sponsor.Code Grant.Category.Code  \
# 0                     1             1          NaN                 NaN
# 1                     2             1           2B                 10A
# 2                     3             1          29A                 10B
# 3                     4             1          40D                 10B
# 4                     5             0          59C                 10A
#
#   Contract.Value.Band...see.note.A Start.date  RFCD.Code.1  RFCD.Percentage.1  \
# 0                               A     8/11/05     280199.0              100.0
# 1                               B    11/11/05     280103.0               30.0
# 2                               A    14/11/05     321004.0               60.0
# 3                               C    15/11/05     270602.0               50.0
# 4                               A    16/11/05     260500.0               34.0
#
# ...

# %%
df.tail()
# Out:
#       Grant.Application.ID  Grant.Status Sponsor.Code Grant.Category.Code  \
# 8703                  8704             1          21A                 50A
# 8704                  8705             1          21A                 50A
# 8705                  8706             0         137A                 30B
# 8706                  8707             1          21A                 50A
# 8707                  8708             1          21A                 50A
#
#      Contract.Value.Band...see.note.A Start.date  RFCD.Code.1  \
# 8703                               A    23/12/08     321028.0
# 8704                               A    23/12/08     340299.0
# 8705                              NaN   24/12/08          NaN
# 8706                               A    24/12/08     280210.0
# 8707                               A    24/12/08     321012.0
#
#       RFCD.Percentage.1  RFCD.Code.2  RFCD.Percentage.2      ...       \
# 8703              100.0          0.0                0.0      ...
# ...

# %%
df2.tail()
# Out:
#       Grant.Application.ID  Grant.Status Sponsor.Code Grant.Category.Code  \
# 8703                  8704             1          21A                 50A
# 8704                  8705             1          21A                 50A
# 8705                  8706             0         137A                 30B
# 8706                  8707             1          21A                 50A
# 8707                  8708             1          21A                 50A
#
#      Contract.Value.Band...see.note.A Start.date  RFCD.Code.1  \
# 8703                               A    23/12/08     321028.0
# 8704                               A    23/12/08     340299.0
# 8705                              NaN   24/12/08          NaN
# 8706                               A    24/12/08     280210.0
# 8707                               A    24/12/08     321012.0
#
#       RFCD.Percentage.1  RFCD.Code.2  RFCD.Percentage.2      ...       \
# 8703              100.0          0.0                0.0      ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8708 entries, 0 to 8707
# Columns: 252 entries, Grant.Application.ID to Unnamed: 251
# dtypes: float64(180), int64(2), object(70)
# memory usage: 16.7+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8708 entries, 0 to 8707
# Columns: 252 entries, Grant.Application.ID to Unnamed: 251
# dtypes: float64(180), int64(2), object(70)
# memory usage: 16.7+ MB

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-77b4ccf4614c> in <module>()
# ----> 1 df[:,1:50]
#
# ~/software/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/software/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/software/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...
